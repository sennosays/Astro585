# %%
include("HW6_Q2_planet_populations_once.jl")
# Out:
# ...
# Loading help data...
# 365.2425

# %%
include("HW6_Q2_planet_populations.jl")
# Out:
# eval_model_on_grid_loops (generic function with 2 methods)
# ...

# %%
include("run_planet_populations.jl");
# Out:
# elapsed time: 110
# .209614877 seconds (180607504 bytes allocated)
# Figure(PyObject <matplotlib.figure.Figure object at 0x10d1604d0>)
# PyObject <matplotlib.text.Text object at 0x111c26350>
